# %% [markdown]
# ### Part 1

# %%
# importing libraries
import numpy as np

# %%
def Power_method_max(A, x0, iter_max, tol):
    """
    Find the largest eigenvalue and eigenvector of a matrix A using the Power Method.

    Parameters:
    - A (numpy.ndarray): The square matrix for which to find the largest eigenvalue and eigenvector.
    - x0 (numpy.ndarray): The initial guess for the eigenvector.
    - iter_max (int): The maximum number of iterations.
    - tol (float): The convergence tolerance.

    Returns:
    - eigenvector (numpy.ndarray): The estimated eigenvector (normalized).
    - eigenvalue (float): The estimated largest eigenvalue.
    - iterations (int): The number of iterations performed.
    """
    prev_eigenvalue = 10

    # Normalize the initial guess
    #x0 = x0 / np.linalg.norm(x0, ord=np.inf)

    for i in range(iter_max):
        x0 = np.dot(A, x0)

        # Scaling the eigenvector
        delta = np.linalg.norm(x0, ord=np.inf)
        x0 = x0 / delta

        # Calculate the corresponding eigenvalue
        eigenvalue = (x0.transpose() @ A @ x0) / (x0.transpose() @ x0)
        
        # Check for convergence
        delta_lambda = np.abs(eigenvalue - prev_eigenvalue)
        print(f"Iteration:{i + 1}  Eigenvalue:{eigenvalue}  Error:{delta_lambda}") 
        if delta_lambda < tol:
            break

        prev_eigenvalue = eigenvalue

    return x0, eigenvalue, i + 1

# %%
# Define the matrices A1, A2, and A3
A1 = np.array([[1, 1, 1], [1, 2, 3], [1, 3, 6]])

# Initial guess for eigenvector
initial_guess = np.array([1, 1, 1])

# Apply Power Method to find dominant eigenvalues and eigenvectors
eigenvector1, eigenvalue1, iterations1 = Power_method_max(A1, initial_guess, 100, 1e-6)

# Print results
print("Matrix A1:")
print("Dominant Eigenvalue:", eigenvalue1)
print("Dominant Eigenvector:", eigenvector1)
print("Number of Iterations:", iterations1)
print()
# Out:
# Iteration:1  Eigenvalue:7.841379310344827  Error:7.841379310344827
# Iteration:2  Eigenvalue:7.872471219403151  Error:0.031091909058323708
# Iteration:3  Eigenvalue:7.872975083359031  Error:0.0005038639558803126
# Iteration:4  Eigenvalue:7.872983212900827  Error:8.129541796186857e-06
# Iteration:5  Eigenvalue:7.872983344056751  Error:1.311559234551396e-07
# Matrix A1:
# Dominant Eigenvalue: 7.872983344056751
# Dominant Eigenvector: [0.22542202 0.54920635 1.        ]
# Number of Iterations: 5

# %%
# Define the matrices A1, A2, and A3
A2 = np.array([[3, 3, 0], [3, 5, 0], [0, 0, 7]])

# Initial guess for eigenvector
initial_guess = np.array([1, 1, 1])

# Apply Power Method to find dominant eigenvalues and eigenvectors
eigenvector2, eigenvalue2, iterations2 = Power_method_max(A2, initial_guess, 100, 1e-6)

print("Matrix A2:")
print("Dominant Eigenvalue:", eigenvalue2)
print("Dominant Eigenvector:", eigenvector2)
print("Number of Iterations:", iterations2)
# Iteration:57  Eigenvalue:7.156391697340401
# Iteration:58  Eigenvalue:7.156646244526597
# Iteration:59  Eigenvalue:7.156890162663541
# Iteration:60  Eigenvalue:7.157123863372134
# Iteration:61  Eigenvalue:7.1573477450808305
# Iteration:62  Eigenvalue:7.157562193206435
# Iteration:63  Eigenvalue:7.157767580356845
# Iteration:64  Eigenvalue:7.15796426655278
# Iteration:65  Eigenvalue:7.158152599465808
# Iteration:66  Eigenvalue:7.158332914670203
# Iteration:67  Eigenvalue:7.158505535906308
# Iteration:68  Eigenvalue:7.1586707753533565
# Iteration:69  Eigenvalue:7.15882893390981
# Iteration:70  Eigenvalue:7.158980301479509
# Iteration:71  Eigenvalue:7.1591251572620305
# Iteration:72  Eigenvalue:7.159263770045863
# Iteration:73  Eigenvalue:7.159396398503079
# Iteration:74  Eigenvalue:7.159523291484402
# Iteration:75  Eigenvalue:7.159644688313598
# Iteration:76  Eigenvalue:7.1597608190803115
# Iteration:77  Eigenvalue:7.159871904930495
# Iteration:78  Eigenvalue:7.1599781583537805
# Iteration:79  Eigenvalue:7.160079783467115
# Iteration:80  Eigenvalue:7.160176976294136
# Iteration:81  Eigenvalue:7.160269925039839
# Iteration:82  Eigenvalue:7.1603588103601075
# Iteration:83  Eigenvalue:7.160443805625803
# Iteration:84  Eigenvalue:7.160525077181096
# Iteration:85  Eigenvalue:7.160602784595856
# Iteration:86  Eigenvalue:7.16067708091188
# Iteration:87  Eigenvalue:7.160748112882844
# Iteration:88  Eigenvalue:7.160816021207878
# Iteration:89  Eigenvalue:7.160880940758665
# Iteration:90  Eigenvalue:7.160943000800084
# Iteration:91  Eigenvalue:7.161002325204323
# Iteration:92  Eigenvalue:7.161059032658531
# Iteration:93  Eigenvalue:7.161113236866011
# Iteration:94  Eigenvalue:7.161165046741018
# Iteration:95  Eigenvalue:7.161214566597236
# Iteration:96  Eigenvalue:7.161261896330017
# Iteration:97  Eigenvalue:7.161307131592462
# Iteration:98  Eigenvalue:7.161350363965493
# Iteration:99  Eigenvalue:7.161391681121973
# Iteration:100  Eigenvalue:7.161431166985056
# Matrix A2:
# Dominant Eigenvalue: 7.161431166985056
# Dominant Eigenvector: [0.72075922 1.         0.08926218]
# Number of Iterations: 100

# %%
# Define the matrices A1, A2, and A3
A3 = np.array([[3, 1, 0], [0, 3, 0], [0, 0, 2]])

# Initial guess for eigenvector
initial_guess = np.array([1, 1, 1])

# Apply Power Method to find dominant eigenvalues and eigenvectors
eigenvector3, eigenvalue3, iterations3 = Power_method_max(A3, initial_guess, 100, 1e-6)

print("Matrix A3:")
print("Dominant Eigenvalue:", eigenvalue3)
print("Dominant Eigenvector:", eigenvector3)
print("Number of Iterations:", iterations3)
